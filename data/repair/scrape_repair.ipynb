# %%
from dataclasses import dataclass, asdict, field
import json


@dataclass
class Solution:
    part: str
    solution: str

@dataclass
class Repair:
    appliance: str = ""
    category: str = ""
    solutions: list[Solution] = field(default_factory=list)
    issue_description_url: str = ""
    video_url: str = ""

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By


def scrape_data(url: str, output_file: str) -> None:
    data = Repair()

    driver = webdriver.Chrome()
    driver.get(url)

    if "dishwasher" in url.lower():
        data.appliance = "Dishwasher"
    elif "refrigerator" in url.lower():
        data.appliance = "Refrigerator"

    # <h1 class="title-main mt-3 mb-3 mb-lg-4&gt;">How To Fix A Noisy Dishwasher</h1>
    title_el = driver.find_element(By.CSS_SELECTOR, 'h1.title-main')
    data.category = title_el.text
    print('category:', title_el.text)

    # find div with class "symptom-list"
    container = driver.find_element(By.CSS_SELECTOR, 'div.symptom-list')
    part_headers = container.find_elements(By.CSS_SELECTOR, 'h2.section-title.bold.col.mt-3.mb-3')
    for h2 in part_headers:
        part = h2.text.strip()

        # find the first following sibling with class "symptom-list__desc"
        desc_block = h2.find_element(
            By.XPATH,
            'following-sibling::div[contains(@class, "symptom-list__desc")][1]'
        )

        # inside that block, the left col-lg-6 is the solution text
        solution_div = desc_block.find_element(By.CSS_SELECTOR, 'div.col-lg-6')
        solution = solution_div.text.strip()

        data.solutions.append(Solution(part=part, solution=solution))
        print('part:', part)
        print('solution:', solution[:120], '...')

        data.issue_description_url = url

    # find video url
    # <img src="https://img.youtube.com/vi/XgZq_VdXKiQ/maxresdefault.jpg" class="yt-video__thumb b-lazy b-loaded loaded" title="How to Fix a Dishwasher That Won’t Start" alt="How to Fix a Dishwasher That Won’t Start">
    video_el = driver.find_element(By.CSS_SELECTOR, 'img[class="yt-video__thumb b-lazy b-loaded loaded"]')
    video_src = video_el.get_attribute("src")
    if "youtube.com/vi/" in video_src:
        video_id = video_src.split("youtube.com/vi/")[1].split("/")[0]
        data.video_url = f"https://www.youtube.com/watch?v={video_id}"
        print('video_url:', data.video_url)

    driver.quit()

    json_data = asdict(data)

    # Save to file
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(json_data, f, ensure_ascii=False, indent=2)

# %%
# urls = [
#     "https://www.partselect.com/Repair/Dishwasher/Noisy/",
#     "https://www.partselect.com/Repair/Dishwasher/Leaking/",
#     "https://www.partselect.com/Repair/Dishwasher/Will-Not-Start/",
#     "https://www.partselect.com/Repair/Dishwasher/Door-Latch-Failure/",
#     "https://www.partselect.com/Repair/Dishwasher/Not-Cleaning-Properly/",
#     "https://www.partselect.com/Repair/Dishwasher/Not-Cleaning-Properly/",
#     "https://www.partselect.com/Repair/Dishwasher/Not-Draining/",
#     "https://www.partselect.com/Repair/Dishwasher/Will-Not-Fill-Water/",
#     "https://www.partselect.com/Repair/Dishwasher/Will-Not-Dispense-Detergent/",
#     "https://www.partselect.com/Repair/Dishwasher/Not-Drying-Properly/",
# ]

urls = [
    "https://www.partselect.com/Repair/Refrigerator/Noisy/",
    "https://www.partselect.com/Repair/Refrigerator/Leaking/",
    "https://www.partselect.com/Repair/Refrigerator/Will-Not-Start/",
    "https://www.partselect.com/Repair/Refrigerator/Not-Making-Ice/",
    "https://www.partselect.com/Repair/Refrigerator/Refrigerator-Too-Warm/",
    "https://www.partselect.com/Repair/Refrigerator/Not-Dispensing-Water/",
    "https://www.partselect.com/Repair/Refrigerator/Refrigerator-Freezer-Too-Warm/",
    "https://www.partselect.com/Repair/Refrigerator/Door-Sweating/",
    "https://www.partselect.com/Repair/Refrigerator/Light-Not-Working/",
    "https://www.partselect.com/Repair/Refrigerator/Refrigerator-Too-Cold/",
    "https://www.partselect.com/Repair/Refrigerator/Running-Too-Long/",
    "https://www.partselect.com/Repair/Refrigerator/Freezer-Too-Cold/"
]

# for output file counter, start at 11
for i, url in enumerate(urls, start=11):
    output_file = f'part_{i}.json'
    scrape_data(url, output_file)
# Out:
# category: How To Fix A Noisy Refrigerator
# part: Condenser Fan Motor
# solution: Most modern frost-free refrigerators will have a fan cooled condenser coil. The condenser fan circulates air through the ...
# part: Evaporator Fan Motor
# solution: The evaporator fan motor is responsible for pulling air over the evaporator coils when the compressor is running. If you ...
# part: Evaporator Fan Motor Grommet
# solution: The evaporator fan motor grommet is used to isolate the motor from the mounting bracket and reduce vibration noise. Regu ...
# video_url: https://www.youtube.com/watch?v=nxHx8mhOnvY
# category: How To Fix Leaking Refrigerator
# part: Door Gaskets Or Seals
# solution: Door gaskets or seals are found along the outside of the refrigerator’s doors. They are normally made from a vinyl mater ...
# part: Water Inlet Valve
# solution: The water inlet valve is a solenoid-operated device that connects your household water supply line to your refrigerator  ...
# part: Ice Maker Assembly
# solution: If your fridge is leaking water from in or around the ice maker, you’re probably also experiencing problems with the ice ...
# video_url: https://www.youtube.com/watch?v=UFqbhptfnwA
# category: How To Fix A Refrigerator That Will Not Start
# part: Overload Or Relay-Start Capacitor
# solution: The overload relay is a protection device used in the compressor circuit on your refrigerator. Power is applied to the c ...
# part: Cold Control & Temperature Control
# solution: The cold control is a temperature-controlled switch that supplies power to the compressor and fan circuits in the refrig ...
# part: Electronic Control Board
# solution: Some newer refrigerators are controlled by an Electronic Control Board that monitors temperatures and controls the compr ...
# video_url: https://www.youtube.com/watch?v=dGdrBnsEZug
# category: How To Fix A Refrigerator That's Not Making Ice
# part: Water Fill Tubes
# solution: Inspect the ice maker mold to see if there are ice cubes present. If there are no cubes or very small cubes, then you sh ...
# part: Water Inlet Valve
# solution: Some water inlet valves may have a screen to filter debris before it can enter the valve. If the screen is plugged, wate ...
# part: Ice & Water Filter
# solution: If equipped, the Ice and Water filter in your refrigerator is responsible for removing any debris or contaminants from y ...
# part: Ice Maker Assembly & Replacement Ice Maker
# solution: If there are no ice buildup issues or suspected problems with the water supply, then you may have a problem with the ice ...
# video_url: https://www.youtube.com/watch?v=I6Sgbo-CB3s
# category: How To Fix A Refrigerator That's Too Warm
# part: Air Inlet Damper Or Baffle
# solution: The air damper, baffle or diffuser is the device that balances the air flow from the evaporator fan housing. This normal ...
# video_url: https://www.youtube.com/watch?v=da9oya03Kvo
# category: How To A Fix Refrigerator That's Not Dispensing Water
# part: Ice & Water Filter
# solution: If so equipped, the ice and water filter in your refrigerator is responsible for removing any debris or contaminants fro ...
# part: Water Inlet Valve
# solution: The water inlet valve is a solenoid-operated device that supplies water to the dispenser when activated. When water is s ...
# part: Water Dispenser Actuator
# solution: The water dispenser actuator is the mechanical part that activates the dispenser micro switch. It is normally a plastic  ...
# part: Micro Switch
# solution: The dispenser micro switch is a momentary contact switch that when actuated will supply power to the solenoid on the wat ...
# part: Dispenser Control Board
# solution: Some models of refrigerators use an electronic control to supply power to the water inlet valve. If you have verified th ...
# video_url: https://www.youtube.com/watch?v=Q8PMGWyvry4
# category: How To Fix A Refrigerator and Freezer That's Too Warm
# part: Cold Control Or Temperature Control
# solution: The cold control is a temperature-controlled switch that supplies power to the compressor and fan circuits in the refrig ...
# part: Evaporator Fan Motor
# solution: The evaporator fan motor is used to circulate the cold air throughout the refrigerator when the compressor is running. I ...
# part: Electronic Control Board
# solution: Some newer models of refrigerators may use an electronic control board. Thermistors or temperature sensors are connected ...
# part: Temperature Sensor Or Thermistor
# solution: In models that use an Electronic Control, a thermistor or temperature sensor may be used to monitor fresh food and freez ...
# part: Defrost Timer
# solution: The defrost timer is an electro-mechanical timer that operates a set of contacts that control both the compressor circui ...
# part: Defrost Thermostat
# solution: The defrost thermostat is a safety thermostat in series with the defrost heater and is used to terminate the defrost cyc ...
# part: Defrost Heater
# solution: The defrost heater is the device that melts the ice and frost from the evaporator coils. It is typically a wire filament ...
# part: Condenser Fan Motor
# solution: Most modern frost-free refrigerators will have a fan cooled condenser coil. This normally located near the compressor at ...
# video_url: https://www.youtube.com/watch?v=da9oya03Kvo
# category: How To Fix A Refrigerator Door That's Sweating
# part: Fresh Food & Freezer Door Gasket
# solution: Leaky or damaged door seals can create excess moisture that is visible near the air outlet ducts or on shelves in the fr ...
# part: Dispenser Door Assembly or Flapper & Ice Door Kit
# solution: When activated, the ice dispenser door opens so that ice can be dispensed from the icemaker. The door or flapper is norm ...
# part: Door Closure Cam Kit
# solution: In some models of side-by-side refrigerators, closer cams on the lower door hinges are used to assist in closing the doo ...
# part: Door Hinge & Bearing
# solution: Fresh food and freezer doors rotate on hinges. The hinges act as bearings and the doors should pivot easily on them. If  ...
# video_url: https://www.youtube.com/watch?v=dGdrBnsEZug
# category: How To Fix A Refrigerator Light That's Not Working
# part: Light Bulb Or Lamp
# solution: Most light bulbs or lamps can be checked visually for a broken filament or can be checked with a multi-meter for continu ...
# part: Light Sockets
# solution: If you have verified that the light bulb or lamp is not defective, then you should next inspect the socket.
# How to inspe ...
# part: Door Light Switch
# solution: The interior light of your refrigerator is controlled by a switch that is activated when the door is opened and closed.  ...
# part: Light Bulb & Ice Dispenser
# solution: If your model has an ice and water dispenser with a light bulb you should first verify that the bulb is good. These ligh ...
# video_url: https://www.youtube.com/watch?v=dGdrBnsEZug
# category: How To Fix A Refrigerator That's Too Cold
# part: Air Inlet Damper Or Baffle
# solution: The air damper, baffle or diffuser is the device that balances the air flow from the evaporator fan housing. This normal ...
# part: Temperature Sensor Or Thermistor
# solution: Some electronic controls models will use a thermistor to sense the temperature. The electronic control monitors this tem ...
# part: Main Control Board
# solution: Some newer models may have an electronic control board that controls all of the refrigerators functions. Sensors are con ...
# part: Cold Control Or Temperature Control
# solution: The cold control thermostat monitors the temperature inside the refrigerator and will operate the compressor and fans wh ...
# video_url: https://www.youtube.com/watch?v=t67G2YUuyWs
# category: How To Fix A Refrigerator That's Running Too Long
# part: Defrost Timer
# solution: The defrost timer can be either a mechanical timer or an electronic "adaptive defrost control". Both are used to initiat ...
# part: Defrost Heater
# solution: The defrost heater is controlled by the defrost timer or adaptive defrost control and the defrost termination thermostat ...
# part: Defrost Termination Thermostat
# solution: The defrost termination thermostat is used as a safety device to turn off the defrost heater when the temperature reache ...
# part: Fresh & Freezer Door Gaskets
# solution: Leaky or damaged door seals can create long run times but normally will just create excess moisture that is visible near ...
# part: Condenser Fan Motor
# solution: If your fridge sounds like it’s running more often than normal, the condenser fan motor could be to blame. If the conden ...
# part: Evaporator Fan Motor
# solution: The evaporator fan is used to draw air over the evaporator coil and circulate the cold air throughout the fresh food and ...
# part: Sealed System
# solution: The sealed system in a refrigerator is comprised of the evaporator, the condenser and the compressor and the associated  ...
# video_url: https://www.youtube.com/watch?v=dGdrBnsEZug
# category: How To Fix A Refrigerator Freezer That's Too Cold
# part: Air Damper Or Freezer Control
# solution: If the freezer section is too cold and the fresh food section temperature is normal you should suspect that the air damp ...
# part: Temperature Sensor Or Thermistor
# solution: In models that use an Electronic Control, a thermistor or temperature sensor may be used to monitor fresh food and freez ...
# video_url: https://www.youtube.com/watch?v=dGdrBnsEZug
